# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('/home/danial/Data Science/Credit Risk Analysis/data/feature-engineered/credit_risk_feature_engineered.csv')
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    ...  fe_pay_delta_1_6  fe_utilization_latest  fe_utilization_mean  \
# 0  ...               0.0               0.195650             0.064200
# 1  ...           -2000.0               0.022350             0.023718
# 2  ...           -3482.0               0.324878             0.188246
# 3  ...            1000.0               0.939800             0.771113
# 4  ...            1321.0               0.172340             0.364463
#
#    fe_pay_to_bill_ratio_latest  fe_pay_to_bill_ratio_6  fe_num_delayed_months  \
# ...

# %%
df = df.drop(columns = ['ID'])

# %%
df['EDUCATION'] = df['EDUCATION'].replace({0:4 , 5:4 , 6:4})
df['MARRIAGE'] = df['MARRIAGE'].replace({0:3})

# %%
df = pd.get_dummies(df , columns = ['SEX' , 'EDUCATION' , 'MARRIAGE'] , drop_first = True)

# %%
target = 'default.payment.next.month'
x = df.drop(columns = [target])
y = df[target]

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(x)

# %%
X_scaled = pd.DataFrame(X_scaled , columns = x.columns)
final_df = pd.concat([X_scaled , y.reset_index(drop = True)] , axis = 1)
final_df.to_csv('/home/danial/Data Science/Credit Risk Analysis/data/processed/credit_ready.csv')
